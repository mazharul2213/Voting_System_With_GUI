# %% [markdown]
# # Voting System

# %%
from tkinter import *
import datetime
from PIL import Image, ImageTk

root = Tk()
root.title("AKMIS House Voting")
myLabel = Label(root, width = '50', text = "Welcome to AKMIS voting system!!")
root.geometry("1300x700")

myLabel = Label(root, width = '355', text = "\nWelcome to *AKMIS* House E-Voting System!!\n", font = 'Helvetica 30 bold', bg = "Green", fg = "White")
#myLabel.grid(row = 1, column = 1)
myLabel.pack()

file = open("voteData.txt", "a+")

voteA = 5
voteB = 0
voteC = 0
voteD = 0

vote2A = 0
vote2B = 0
vote2C = 0
vote2D = 0

vote3A = 0
vote3B = 0
vote3C = 0
vote3D = 0
vote3E = 0

vote4A = 0
vote4B = 0
vote4C = 0
vote4D = 0

frame = Frame(root, width = 50, borderwidth = 10, bg = "white", relief = SUNKEN)
frame.pack(side=TOP, anchor="nw")

frame2 = Frame(root, width = 50, borderwidth = 10, bg = "white", relief = SUNKEN)
frame2.pack(side=TOP, anchor="nw")

frame3 = Frame(root, width = 50, borderwidth = 10, bg = "white", relief = SUNKEN)
frame3.pack(side=TOP, anchor="nw")

frame4 = Frame(root, width = 50, borderwidth = 10, bg = "white", relief = SUNKEN)
frame4.pack(side=TOP, anchor="nw")



def orng():
    b1.pack_forget()
    b2.pack_forget()
    b3.pack_forget()
    b4.pack_forget()
    label.pack_forget()
    
    file.write("\n\n\n********************************* Orange House ********************************\n\n")
    
    def voteA():
        global voteA
        voteA = voteA + 3
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Nasryn got = ", voteA, " Votes", " at Time = ", TimeNow)
        u1 = "Nasryn = ", voteA, " Time =", TimeNow
        file.write(str(u1))  
        file.write("\n")
        
    def voteB():
        global voteB
        voteB = voteB + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Rikta got = ",voteB, " Votes", " at Time = ", TimeNow)
        u2 = "Rikta =", voteB, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
        
    def voteC():
        global voteC
        voteC = voteC + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Bushra got = ", voteC, " Votes", " at Time = ", TimeNow)
        u2 = "Bushra =", voteC, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    def voteD():
        global voteD
        voteD = voteD + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Anandita got = ", voteD, "Votes", " at Time = ", TimeNow) 
        u2 = "Anandita =", voteD, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    
    cp = Button(frame, width = '100', text = "Select Captain!!", font = 'Helvetica 20 bold', bg = "white", fg = "black")
    #myLabel.grid(row = 1, column = 1)
    cp.pack(side=LEFT, pady = 20)
    
    v1 = Button(frame2, fg="orange", width = "55", text="Nasryn Kasara Hossain", font = 'Helvetica 15 bold', command = voteA)
    v1.pack(side=LEFT, pady = 20)
    v1 = Button(frame2, fg="orange", width = "55", text="Merazul Hasan Rikta", font = 'Helvetica 15 bold', command = voteB)
    v1.pack(side=LEFT, pady = 20)
    
    vcp = Button(frame3, width = '100', text = "Select Vice-Captain!!", font = 'Helvetica 20 bold', bg = "white", fg = "black")
    #myLabel.grid(row = 1, column = 1)
    vcp.pack(side = LEFT, pady = 10)
    
    v1B = Button(frame4, fg="orange", width = "55", text="Bushra Tabassum Dippannita", font = 'Helvetica 15 bold', command = voteC)
    v1B.pack(side=LEFT, pady = 10)
    v1B = Button(frame4, fg="orange", width = "55", text="Anandita Sattar", font = 'Helvetica 15 bold', command = voteD)
    v1B.pack(side=LEFT, pady = 10)
    
def blu():
    b1.pack_forget()
    b2.pack_forget()
    b3.pack_forget()
    b4.pack_forget()
    label.pack_forget()
    
    file.write("\n\n\n********************************* Blue House ********************************\n\n")
    
    def vote2A():
        global vote2A
        vote2A = vote2A + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Meela got = ", vote2A, "Votes", " at Time = ", TimeNow)
        u2 = "Meela =", vote2A, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    def vote2B():
        global vote2B
        vote2B = vote2B + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Rishad got = ", vote2B, "Votes", " at Time = ", TimeNow)
        u2 = "Rishad =", vote2B, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    def vote2C():
        global vote2C
        vote2C = vote2C + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Bina got = ", vote2C, "Votes", " at Time = ", TimeNow)
        u2 = "Bina =", vote2C, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    def vote2D():
        global vote2D
        vote2D = vote2D + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Miftahul got = ", vote2D, "Votes", " at Time = ", TimeNow)
        u2 = "Miftahul =", vote2D, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    
    cp = Button(frame, width = '100', text = "Select Captain!!", font = 'Helvetica 20 bold', bg = "white", fg = "black")
    #myLabel.grid(row = 1, column = 1)
    cp.pack(side=LEFT, pady = 20)
    
    v2 = Button(frame2, fg="blue", width = "55", text="Samia Alam Meela", font = 'Helvetica 15 bold', command = vote2A)
    v2.pack(side=LEFT, pady = 20)
    v2 = Button(frame2, fg="blue", width = "55", text="Md. Abu Talha Rishad", font = 'Helvetica 15 bold', command = vote2B)
    v2.pack(side=LEFT, pady = 20)
    
    vcp = Button(frame3, width = '100', text = "Select Vice-Captain!!", font = 'Helvetica 20 bold', bg = "white", fg = "black")
    #myLabel.grid(row = 1, column = 1)
    vcp.pack(side=LEFT, pady = 20)
    
    v2 = Button(frame4, fg="blue", width = "55", text="Samia Zaman Bina", font = 'Helvetica 15 bold', command = vote2C)
    v2.pack(side=LEFT, pady = 20)
    v2 = Button(frame4, fg="blue", width = "55", text="Miftahul Zannat Prithibi", font = 'Helvetica 15 bold', command = vote2D)
    v2.pack(side=LEFT, pady = 20)
    
def ylo():
    b1.pack_forget()
    b2.pack_forget()
    b3.pack_forget()
    b4.pack_forget()
    label.pack_forget()
    
    file.write("\n\n\n********************************* Yellow House ********************************\n\n")
    
    def vote3A():
        global vote3A
        vote3A = vote3A + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Sunjim got = ", vote3A, "Votes", " at Time = ", TimeNow)
        u2 = "Sunjim =", vote3A, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    def vote3B():
        global vote3B
        vote3B = vote3B + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Mohit got = ", vote3B, "Votes", " at Time = ", TimeNow)
        u2 = "Mohit =", vote3B, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    def vote3C():
        global vote3C
        vote3C = vote3C + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Sudipto got = ", vote3C, "Votes", " at Time = ", TimeNow)
        u2 = "Sudipto =", vote3C, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    def vote3D():
        global vote3D
        vote3D = vote3D + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Anoya got = ", vote3D, "Votes", " at Time = ", TimeNow)
        u2 = "Anoya =", vote3D, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    def vote3E():
        global vote3E
        vote3E = vote3E + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Noyan got = ", vote3E, "Votes", " at Time = ", TimeNow)
        u2 = "Noyan =", vote3E, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    
    cp = Button(frame, width = '100', text = "Select Captain!!", font = 'Helvetica 20 bold', bg = "white", fg = "black")
    #myLabel.grid(row = 1, column = 1)
    cp.pack(side=LEFT, pady = 20)
    
    v3 = Button(frame2, fg="#8B8000", width = "38", text="Sunjim Hossain", font = 'Helvetica 15 bold', command = vote3A)
    v3.pack(side=LEFT, pady = 20)
    v3 = Button(frame2, fg="#8B8000", width = "38", text="Saifur Rahman Mohit", font = 'Helvetica 15 bold', command = vote3B)
    v3.pack(side=LEFT, pady = 20)
    v3 = Button(frame2, fg="#8B8000", width = "38", text="Sudipto Roy", font = 'Helvetica 15 bold', command = vote3C)
    v3.pack(side=LEFT, pady = 20)
    
    vcp = Button(frame3, width = '100', text = "Select Vice-Captain!!", font = 'Helvetica 20 bold', bg = "white", fg = "black")
    #myLabel.grid(row = 1, column = 1)
    vcp.pack(side=LEFT, pady = 20)
    
    v3 = Button(frame4, fg="#8B8000", width = "55", text="Rayeta Tarannom Anoya", font = 'Helvetica 15 bold', command = vote3D)
    v3.pack(side=LEFT, pady = 20)
    v3 = Button(frame4, fg="#8B8000", width = "55", text="Mehedi Hasan Noyan", font = 'Helvetica 15 bold', command = vote3E)
    v3.pack(side=LEFT, pady = 20)
    
def prpl():
    b1.pack_forget()
    b2.pack_forget()
    b3.pack_forget()
    b4.pack_forget()
    label.pack_forget()
    
    file.write("\n\n\n********************************* Purple House ********************************\n\n")
    
    def vote4A():
        global vote4A
        vote4A = vote4A + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Shreonty got = ", vote4A, "Votes", " at Time = ", TimeNow)
        u2 = "Shreonty =", vote4A, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    def vote4B():
        global vote4B
        vote4B = vote4B + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Hasibuzzaman got", vote4B, "Votes", " at Time = ", TimeNow)
        u2 = "Hasibuzzaman =", vote4B, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    def vote4C():
        global vote4C
        vote4C = vote4C + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Ahnaf got = ", vote4C, "Votes", " at Time = ", TimeNow)
        u2 = "Ahnaf =", vote4C, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    def vote4D():
        global vote4D
        vote4D = vote4D + 1
        TimeNow = datetime.datetime.now()
        TimeNow = TimeNow.replace(microsecond = 0)
        print("Sujana got = ", vote4D, "Votes", " at Time = ", TimeNow)
        u2 = "Sujana =", vote4D, " Time =", TimeNow
        file.write(str(u2))
        file.write("\n")
    
    cp = Button(frame, width = '100', text = "Select Captain!!", font = 'Helvetica 20 bold', bg = "white", fg = "black")
    #myLabel.grid(row = 1, column = 1)
    cp.pack(side=LEFT, pady = 20)
    
    v4 = Button(frame2, fg="purple", width = "55", text="Anusheh Anadil Shreonty", font = 'Helvetica 15 bold', command = vote4A)
    v4.pack(side=LEFT, pady = 20)
    v4 = Button(frame2, fg="purple", width = "55", text="Hasibuzzaman Sarkar", font = 'Helvetica 15 bold', command = vote4B)
    v4.pack(side=LEFT, pady = 20)
    
    vcp = Button(frame3, width = '100', text = "Select Vice-Captain!!", font = 'Helvetica 20 bold', bg = "white", fg = "black")
    #myLabel.grid(row = 1, column = 1)
    vcp.pack(side=LEFT, pady = 20)
    
    v4 = Button(frame4, fg="purple", width = "55", text="Mohammad Ahnaf", font = 'Helvetica 15 bold', command = vote4C)
    v4.pack(side=LEFT, pady = 20)
    v4 = Button(frame4, fg="purple", width = "55", text="Samiya Alam Sujana", font = 'Helvetica 15 bold', command = vote4D)
    v4.pack(side=LEFT, pady = 20)


b1 = Button(frame, fg = "white" , bg="orange", width = "22", text="Orange House", font = 'Helvetica 18 bold', command = orng)
b1.pack(side=LEFT, pady = 20)

b2 = Button(frame, fg = "white" , bg="blue", width = "22", text="Blue House", font = 'Helvetica 18 bold', command = blu)
b2.pack(side=LEFT, pady = 20)

b3 = Button(frame, fg = "white" , bg="#8B8000", width = "22", text="Yellow House", font = 'Helvetica 18 bold', command = ylo)
b3.pack(side=LEFT, pady = 20)

b4 = Button(frame, fg = "white" , bg="purple", width = "22", text="Purple House", font = 'Helvetica 18 bold', command = prpl)
b4.pack(side=LEFT, pady = 20)
#b4.pack(side=TOP, pady = 20)

myLabel = Label(root, width = '355', height= "5", text = "", font = 'Helvetica 10', bg = "#f2f0f5", fg = "black")
#myLabel.grid(row = 1, column = 1)
myLabel.pack()

image = Image.open('akmis.png')
photo = ImageTk.PhotoImage(image)

label = Label(image = photo, bg = "#f2f0f5")
label.pack()

myLabel = Label(root, width = '355', height= "5", text = "", font = 'Helvetica 10', bg = "#f2f0f5", fg = "black")
#myLabel.grid(row = 1, column = 1)
myLabel.pack()
myLabel = Label(root, width = '355', text = "\nCopyright - S. M. Mazharul Hoque Chowdhury!\n", font = 'Helvetica 10', bg = "Gray", fg = "black")
#myLabel.grid(row = 1, column = 1)
myLabel.pack()


root.mainloop()
file.close()
# Out:
# Nasryn got =  8  Votes  at Time =  2022-11-27 09:27:25
# Nasryn got =  11  Votes  at Time =  2022-11-27 09:27:30
